# %%
display(dbutils.fs.ls("/databricks-datasets/samples/docs/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/samples/docs/README.md</td><td>README.md</td><td>3137</td></tr></tbody></table></div>

# %%
textFile = spark.read.text("/databricks-datasets/samples/docs/README.md")
textFile.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: 65</div>

# %%
textFile.first()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: Row(value=&#39;Welcome to the Spark documentation!&#39;)</div>

# %%
linesWithspark = textFile.filter(textFile.value.contains("spark"))
linesWithspark.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: 1</div>

# %%
linesWithspark.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: [Row(value=&#39;Spark at http://spark.apache.org/documentation.html.&#39;)]</div>

# %%
linesWithSpark = textFile.filter(textFile.value.contains("Spark"))
linesWithSpark.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: 12</div>

# %%
linesWithSpark
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: DataFrame[value: string]</div>

# %%
linesWithSpark.take(15)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: [Row(value=&#39;Welcome to the Spark documentation!&#39;),
#  Row(value=&#39;This readme will walk you through navigating and building the Spark documentation, which is included&#39;),
#  Row(value=&#39;here with the Spark source code. You can also find documentation specific to release versions of&#39;),
#  Row(value=&#39;Spark at http://spark.apache.org/documentation.html.&#39;),
#  Row(value=&#39;whichever version of Spark you currently have checked out of revision control.&#39;),
#  Row(value=&#39;The Spark documentation build uses a number of tools to build HTML docs and API docs in Scala,&#39;),
#  Row(value=&#39;We include the Spark documentation as part of the source (as opposed to using a hosted wiki, such as&#39;),
#  Row(value=&#39;You can build just the Spark scaladoc by running `build/sbt unidoc` from the SPARK_PROJECT_ROOT directory.&#39;),
#  Row(value=&#39;Similarly, you can build just the PySpark docs by running `make html` from the&#39;),
#  Row(value=&#39;public in `__init__.py`. The SparkR docs can be built by running SPARK_PROJECT_ROOT/R/create-docs.sh.&#39;),
#  Row(value=&#39;Spark subprojects into the `docs` directory (and then also into the `_site` directory). We use a&#39;),
#  Row(value=&#39;PySpark docs [Sphinx](http://sphinx-doc.org/).&#39;)]</div>
